# %% [markdown]
# ### Pandas

# %% [markdown]
# ### What kind of data does pandas handle?

# %%
import pandas as pd

# %%
df = pd.DataFrame({
   ...:     "Name": ["Braund, Mr. Owen Harris",
   ...:              "Allen, Mr. William Henry",
   ...:              "Bonnell, Miss. Elizabeth"],
   ...:     "Age": [22, 35, 58],
   ...:     "Sex": ["male", "male", "female"]}
   ...: )

# %%
df
# Out:
#                        Name  Age     Sex
# 0   Braund, Mr. Owen Harris   22    male
# 1  Allen, Mr. William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   58  female

# %%
df = pd.DataFrame({
    "Name": ["Panday, Ms. Nmn",
            "Sigdel, Ms. Niharika,",
            "Sigdel, Mr. Dks"],
    "Age": [36, 1, 37],
    "Sex": ["female", "female", "male"],
    "Country": ["Nepal", "USA", "Nepal"]
})

# %%
df
# Out:
#                     Name  Age     Sex Country
# 0        Panday, Ms. Nmn   36  female   Nepal
# 1  Sigdel, Ms. Niharika,    1  female     USA
# 2        Sigdel, Mr. Dks   37    male   Nepal

# %% [markdown]
# ### let's try only with age column

# %%
df["Age"]
# Out:
# 0    36
# 1     1
# 2    37
# Name: Age, dtype: int64

# %%
df["Age"].max()
# Out:
# 37

# %%
df["Age"].min()
# Out:
# 1

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   24.666667
# std    20.502032
# min     1.000000
# 25%    18.500000
# 50%    36.000000
# 75%    36.500000
# max    37.000000

# %% [markdown]
# ### How to read and write tabular data

# %%
titanic = pd.read_csv("data/titanic.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ### I want to see the first 8 rows of a pandas DataFrame.

# %%
titanic.head(8)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %% [markdown]
# ### To check the each of the column's data types

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ### If my colleague requested the titanic data as spreadsheet.

# %%
titanic.to_excel('titanic.xlsx', sheet_name='passanger', index=False)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# ### How do I select a subset of a DataFrame?

# %% [markdown]
# ### If I want to know the age of the titanic passangers.

# %%
ages = titanic["Age"]   #---To select single column use the [] with column name of interest

# %%
ages.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
titanic["Age"].shape
# Out:
# (891,)

# %% [markdown]
# ### If I want to know the age and sex of the titanic passangers.

# %%
age_sex = titanic[["Age", "Sex"]]

# %%
age_sex.head()
# Out:
#     Age     Sex
# 0  22.0    male
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 4  35.0    male

# %%
age_sex = titanic[["Age", "Sex"]].shape

# %%
age_sex
# Out:
# (891, 2)

# %% [markdown]
# ### How do I filter specific rows from a DataFrame?

# %% [markdown]
# #### If I want to know the passangers older than 35 years.

# %%
above_35 = titanic[titanic["Age"]>35]

# %%
above_35.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 6             7         0       1
# 11           12         1       1
# 13           14         0       3
# 15           16         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 6       0     17463  51.8625   E46        S
# 11      0    113783  26.5500  C103        S
# 13      5    347082  31.2750   NaN        S
# 15      0    248706  16.0000   NaN        S

# %%
above_35.shape
# Out:
# (217, 12)

# %%
below_18 = titanic.loc[titanic["Age"]<18]

# %%
below_18.shape
# Out:
# (113, 12)

# %%
exact_20 = titanic[titanic["Age"]==20]

# %%
exact_20.shape
# Out:
# (15, 12)

# %% [markdown]
# ### If I want to know the titanic passangers from cabin class 2 and 3.

# %%
cabin_23 = titanic[titanic["Pclass"].isin([2,3])]

# %%
cabin_23.shape
# Out:
# (675, 12)

# %%
cabin_23 = titanic[(titanic["Pclass"]==2) | (titanic["Pclass"]==3)]

# %%
cabin_23.shape
# Out:
# (675, 12)

# %% [markdown]
# ### I want to work with passsenger data for which the age is known.

# %%
age_no_na = titanic[titanic["Age"].notna()]

# %%
age_no_na.shape
# Out:
# (714, 12)

# %% [markdown]
# ### How do I select specific rows and columns from a DataFrame?

# %%
adult_names = titanic.loc[titanic["Age"] > 35, "Name"]

# %%
adult_names.head()
# Out:
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 6                               McCarthy, Mr. Timothy J
# 11                             Bonnell, Miss. Elizabeth
# 13                          Andersson, Mr. Anders Johan
# 15                     Hewlett, Mrs. (Mary D Kingcome)
# Name: Name, dtype: object

# %% [markdown]
# ### I am interested in rows 10 till 25 and columns 3 to 5

# %%
titanic.iloc[9:25, 2:5]
# Out:
#     Pclass                                               Name     Sex
# 9        2                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10       3                    Sandstrom, Miss. Marguerite Rut  female
# 11       1                           Bonnell, Miss. Elizabeth  female
# 12       3                     Saundercock, Mr. William Henry    male
# 13       3                        Andersson, Mr. Anders Johan    male
# 14       3               Vestrom, Miss. Hulda Amanda Adolfina  female
# 15       2                   Hewlett, Mrs. (Mary D Kingcome)   female
# 16       3                               Rice, Master. Eugene    male
# 17       2                       Williams, Mr. Charles Eugene    male
# 18       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female
# 19       3                            Masselmani, Mrs. Fatima  female
# 20       2                               Fynney, Mr. Joseph J    male
# ...

# %%
titanic.iloc[0:5, 3] = "anonymous"

# %%
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                          anonymous    male  22.0      1
# 1                                          anonymous  female  38.0      1
# 2                                          anonymous  female  26.0      0
# 3                                          anonymous  female  35.0      1
# 4                                          anonymous    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# ### Plotting in the Pandas

# %%
import matplotlib.pyplot as plt

# %%
ages.plot()

# %%
titanic["Fare"].plot()

# %% [markdown]
# ### How to creat new columns derived from existing columns

# %%
titanic["modified_Fare"] = titanic["Fare"]*10

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass       Name     Sex   Age  SibSp  Parch  \
# 0            1         0       3  anonymous    male  22.0      1      0
# 1            2         1       1  anonymous  female  38.0      1      0
# 2            3         1       3  anonymous  female  26.0      0      0
# 3            4         1       1  anonymous  female  35.0      1      0
# 4            5         0       3  anonymous    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  modified_Fare
# 0         A/5 21171   7.2500   NaN        S         72.500
# 1          PC 17599  71.2833   C85        C        712.833
# 2  STON/O2. 3101282   7.9250   NaN        S         79.250
# 3            113803  53.1000  C123        S        531.000
# 4            373450   8.0500   NaN        S         80.500

# %% [markdown]
# ### I want to check the ratio of the Fares

# %%
titanic["ratio_modified_Fare_Fare"] = titanic["modified_Fare"]/titanic["Fare"]

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass       Name     Sex   Age  SibSp  Parch  \
# 0            1         0       3  anonymous    male  22.0      1      0
# 1            2         1       1  anonymous  female  38.0      1      0
# 2            3         1       3  anonymous  female  26.0      0      0
# 3            4         1       1  anonymous  female  35.0      1      0
# 4            5         0       3  anonymous    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  modified_Fare  \
# 0         A/5 21171   7.2500   NaN        S         72.500
# 1          PC 17599  71.2833   C85        C        712.833
# 2  STON/O2. 3101282   7.9250   NaN        S         79.250
# 3            113803  53.1000  C123        S        531.000
# 4            373450   8.0500   NaN        S         80.500
#
#    ratio_modified_Fare_Fare
# 0                      10.0
# 1                      10.0
# 2                      10.0
# 3                      10.0
# 4                      10.0

# %% [markdown]
# ### I want to rename the data columns

# %%
titanic_renamed = titanic.rename(
    columns= {"Survived": "Bacheka",
             "Name": "Nam",
             "Age": "Barsa"})

# %%
titanic_renamed.head()
# Out:
#    PassengerId  Bacheka  Pclass        Nam     Sex  Barsa  SibSp  Parch  \
# 0            1        0       3  anonymous    male   22.0      1      0
# 1            2        1       1  anonymous  female   38.0      1      0
# 2            3        1       3  anonymous  female   26.0      0      0
# 3            4        1       1  anonymous  female   35.0      1      0
# 4            5        0       3  anonymous    male   35.0      0      0
#
#              Ticket     Fare Cabin Embarked  modified_Fare  \
# 0         A/5 21171   7.2500   NaN        S         72.500
# 1          PC 17599  71.2833   C85        C        712.833
# 2  STON/O2. 3101282   7.9250   NaN        S         79.250
# 3            113803  53.1000  C123        S        531.000
# 4            373450   8.0500   NaN        S         80.500
#
#    ratio_modified_Fare_Fare
# 0                      10.0
# 1                      10.0
# 2                      10.0
# 3                      10.0
# 4                      10.0

# %% [markdown]
# ### How to calculate the summary statistics

# %%
titanic["Age"].mean()
# Out:
# 29.69911764705882

# %% [markdown]
# ### What is the median age and ticket fare price of the Titanic passengers?

# %%
titanic[["Age", "Fare"]].median()
# Out:
# Age     28.0000
# Fare    14.4542
# dtype: float64

# %%
titanic.agg({'Age': ['min', 'max', 'median', 'skew'],
                'Fare': ['min', 'max', 'median', 'mean']})
# Out:
#               Age        Fare
# max     80.000000  512.329200
# mean          NaN   32.204208
# median  28.000000   14.454200
# min      0.420000    0.000000
# skew     0.389108         NaN

# %% [markdown]
# ### Aggregating statistics grouped by category

# %% [markdown]
# ### What is the average age for male versus female Titanic passengers?

# %%
titanic[["Sex", "Age"]].groupby("Sex").mean()
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
titanic.groupby("Sex").mean()
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare  modified_Fare  ratio_modified_Fare_Fare
# Sex
# female  44.479818     444.798178                      10.0
# male    25.523893     255.238934                      10.0

# %%
titanic.groupby("Sex")["Age"].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %% [markdown]
# ### What is the mean ticket fare price for each of the sex and cabin class combinations?

# %%
titanic.groupby(["Sex","Pclass"])["Fare"].mean()
# Out:
# Sex     Pclass
# female  1         106.125798
#         2          21.970121
#         3          16.118810
# male    1          67.226127
#         2          19.741782
#         3          12.661633
# Name: Fare, dtype: float64

# %% [markdown]
# ### What is the number of passengers in each of the cabin classes?

# %%
titanic["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
titanic.groupby("Pclass")["Pclass"].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %% [markdown]
# ### How to reshape the layout of tables?
# ### Sort table rows (I want to sort the Titanic data according to the age of the passengers)

# %%
titanic.sort_values(by="Age").head()
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked  modified_Fare  \
# 803  0.42      0      1    2625   8.5167   NaN        C         85.167
# 755  0.67      1      1  250649  14.5000   NaN        S        145.000
# 644  0.75      2      1    2666  19.2583   NaN        C        192.583
# 469  0.75      2      1    2666  19.2583   NaN        C        192.583
# 78   0.83      0      2  248738  29.0000   NaN        S        290.000
#
#      ratio_modified_Fare_Fare
# 803                      10.0
# ...

# %% [markdown]
# ### I want to sort the Titanic data according to the cabin class and age in descending order.

# %%
titanic.sort_values(by = ["Pclass","Age"], ascending = False).head()
# Out:
#      PassengerId  Survived  Pclass                       Name     Sex   Age  \
# 851          852         0       3        Svensson, Mr. Johan    male  74.0
# 116          117         0       3       Connors, Mr. Patrick    male  70.5
# 280          281         0       3           Duane, Mr. Frank    male  65.0
# 483          484         1       3     Turkula, Mrs. (Hedwig)  female  63.0
# 326          327         0       3  Nysveen, Mr. Johan Hansen    male  61.0
#
#      SibSp  Parch  Ticket    Fare Cabin Embarked  modified_Fare  \
# 851      0      0  347060  7.7750   NaN        S         77.750
# 116      0      0  370369  7.7500   NaN        Q         77.500
# 280      0      0  336439  7.7500   NaN        Q         77.500
# 483      0      0    4134  9.5875   NaN        S         95.875
# 326      0      0  345364  6.2375   NaN        S         62.375
#
#      ratio_modified_Fare_Fare
# 851                      10.0
# 116                      10.0
# ...
